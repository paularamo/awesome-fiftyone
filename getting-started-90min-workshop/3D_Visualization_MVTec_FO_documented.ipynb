# %% [markdown]
# # FiftyOne Workshop: Complex Datasets - MVTec 3D Anomaly Detection Dataset into FiftyOne (March 12th 2025)
#
# This notebook demonstrates how to integrate the **MVTec 3D Anomaly Detection Dataset** into FiftyOne.
# The dataset contains high-resolution 3D scans of objects, including **point cloud data** and **RGB images**,
# which are useful for anomaly detection tasks.
#
# ![Image](https://github.com/user-attachments/assets/acf9f1b7-1edf-42b3-83ef-1ef1f7de5cfb)
#
# ## 🏆 Learning Objectives:
# - Convert TIFF to PCD format for visualization in FiftyOne.
# - Create a Grouped Dataset in FiftyOne
# - Leverage FiftyOne for visualization and analysis.
#
# ### Key Features:
# - **3D Representation**: The dataset provides XYZ point cloud representations stored as TIFF files.
# - **RGB and Mask Images**: Each sample includes an RGB image and a corresponding segmentation mask.
# - **Anomalous and Normal Samples**: The dataset includes both normal and defective objects for anomaly detection research.
# - **Grouped Datasets in FiftyOne**: FiftyOne supports the creation of grouped dataset which contain multiple modalities
#
# To make this dataset compatible with FiftyOne, we need to **convert TIFF files into PCD (Point Cloud Data) format**
# for visualization.

# %% [markdown]
# ## Converting TIFF to PCD for Visualization
#
# MVTec 3D provides **XYZ coordinate data stored in TIFF format**, which must be converted to **PCD format**
# to be visualized in FiftyOne. The function below:
# 1. Loads the TIFF file as a **NumPy array**.
# 2. Reshapes it into **Nx3 (XYZ points) format**.
# 3. Saves it as a **PCD file** using Open3D.
#
# Additionally, another function includes **color segmentation** from masks to highlight anomalies.
#
# We are not going to run this in the workshop, but we will provide you the PCD files as well. The next three cells are for your reference, so you can take a look of how convert from TIFF to PCD.

# %%
# Before to start install the following libraries in this environment
#!pip install open3d

# %%
# import os
# import fiftyone as fo
# import numpy as np
# import open3d as o3d
# import tifffile

# def convert_tiff_xyz_to_pcd(tiff_path, pcd_path):
#     # Load the TIFF as a NumPy array
#     xyz_data = tifffile.imread(tiff_path)
    
#     if xyz_data.ndim == 3 and xyz_data.shape[2] == 3:
#         # If the data is in the shape (H, W, 3), reshape it to (H*W, 3)
#         xyz_data = xyz_data.reshape(-1, 3)
#     elif xyz_data.ndim == 2 and xyz_data.shape[1] == 3:
#         # Already in Nx3 shape; no need to reshape
#         pass  
#     else:
#         raise ValueError(f"Unexpected TIFF shape {xyz_data.shape}; adapt code as needed.")
    
#     # Create an Open3D point cloud from the reshaped data
#     pcd = o3d.geometry.PointCloud()
#     pcd.points = o3d.utility.Vector3dVector(xyz_data)
    
#     # Save the point cloud to a .pcd file
#     o3d.io.write_point_cloud(pcd_path, pcd)

# # Example usage
# #convert_tiff_xyz_to_pcd("/home/paula/projects/anomaly_CVPR/mvtec_3d/bagel/train/good/xyz/000.tiff", "example_xyz2.pcd")

# %%
# import numpy as np
# import open3d as o3d
# import tifffile

# def convert_tiff_xyz_to_pcd_with_color(tiff_path, mask_path, pcd_path):
#     """
#     Converts a .xyz TIFF file into a PCD file, adding color information from a mask.
    
#     Assumes:
#       - The TIFF file has shape (H, W, 3) and represents point coordinates.
#       - The mask has shape (H, W) and is aligned with the TIFF data.
      
#     Points corresponding to mask > 0 are colored red; others are colored light gray.
#     """
#     # Load the point coordinates from the TIFF and the segmentation mask
#     xyz_data = tifffile.imread(tiff_path)
#     mask = tifffile.imread(mask_path)
    
#     # Ensure the shapes match spatially
#     if xyz_data.ndim == 3 and xyz_data.shape[2] == 3:
#         H, W, _ = xyz_data.shape
#         if mask.shape[0] != H or mask.shape[1] != W:
#             raise ValueError("The mask dimensions do not match the TIFF image dimensions.")
#         # Flatten the point coordinates and mask to align one-to-one.
#         points = xyz_data.reshape(-1, 3)
#         mask_flat = mask.reshape(-1)
#     else:
#         raise ValueError(f"Unexpected TIFF shape {xyz_data.shape}; expected (H,W,3)")
    
#     # Create a color array for each point.
#     colors = np.zeros((points.shape[0], 3))
#     # For example, assign red to segmented areas (mask > 0) and light gray elsewhere.
#     colors[mask_flat > 0] = [1, 0, 0]      # Red for segmentation
#     colors[mask_flat == 0] = [0.7, 0.7, 0.7] # Light gray for background
    
#     # Create the Open3D point cloud and assign both points and colors.
#     pcd = o3d.geometry.PointCloud()
#     pcd.points = o3d.utility.Vector3dVector(points)
#     pcd.colors = o3d.utility.Vector3dVector(colors)
    
#     # Write the colored point cloud to the specified PCD file.
#     o3d.io.write_point_cloud(pcd_path, pcd)

# # Example usage:
# # convert_tiff_xyz_to_pcd_with_color("path/to/example.tiff", "path/to/example_mask.png", "path/to/colored_example.pcd")

# %% [markdown]
# ## Creating a Grouped Dataset in FiftyOne
#
# FiftyOne allows creating **grouped datasets**, where multiple data modalities (e.g., RGB images,
# segmentation masks, and point clouds) can be linked together under a common identifier. This enables:
# - **Synchronized visualization**: Easily switch between different representations of the same object.
# - **Multi-modal analysis**: Combine insights from images, masks, and 3D data.
#
# This notebook demonstrates how to create a grouped dataset where each sample includes:
# - An **RGB image**
# - A **segmentation mask**
# - A **3D point cloud (PCD)**
#
# We will use `potato` object from the [MVTec 3D Dataset](https://www.mvtec.com/company/research/datasets/mvtec-3d-ad/), here are the modified subset of the dataset.
#
# You can download the subset here [Potato MVTec 3D](https://huggingface.co/datasets/pjramg/potato_mvtec3d). Please download the dataset to disk and add samples in FiftyOne as I am showing you in the following cell.
#
# <div style="border-left: 4px solid #3498db; padding: 6px;">
# <strong>Note:</strong> Loaing this dataset using the hugging Face hub won't work because it is not in saved in FiftyOne format.

# %% [markdown]
# ### Create the Dataset instance in FiftyOne

# %%
import fiftyone as fo

# Create an empty dataset
dataset = fo.Dataset("potato_mvtec", persistent=True, overwrite=True)

# %% [markdown]
# ### Read the MVTec Directory (potato object) and creating pair of metadata before grouping dataset in FiftyOne

# %%
import os

def process_potato_folder(root):
    """
    Walks the directory tree under root (e.g. "potato") to create a list of dictionaries,
    each containing the paths for the rgb image, mask, and the existing PCD file.
    
    It extracts metadata from the folder structure (e.g. split and quality) and assigns a label:
      - "normal" if quality == "good"
      - "abnormal" otherwise.
    
    Assumes that the folder structure is as follows:
    
      potato/
          <split>/
              <quality>/   (e.g., "good" or "defective")
                  rgb/    <-- contains .png images
                  gt/     <-- contains corresponding mask .png images
                  pcd/    <-- contains pre-computed .pcd files
    """
    pairs = []
    # Walk the tree looking for "rgb" folders
    for dirpath, dirnames, filenames in os.walk(root):
        if os.path.basename(dirpath).lower() != "rgb":
            continue

        # Expected structure: .../<split>/<quality>/rgb
        quality_folder = os.path.basename(os.path.dirname(dirpath))
        split_folder = os.path.basename(os.path.dirname(os.path.dirname(dirpath)))
        print(f"Processing folder: {dirpath} (split: {split_folder}, quality: {quality_folder})")
        
        # Define corresponding folders for masks (gt) and PCD files (pcd)
        parent_dir = os.path.dirname(dirpath)
        gt_dir = os.path.join(parent_dir, "gt")
        pcd_dir = os.path.join(parent_dir, "pcd")
        print(f"Looking for PCD files in: {pcd_dir}")
        
        for file in filenames:
            if file.lower().endswith(".png"):
                base_name = os.path.splitext(file)[0]
                image_path = os.path.join(dirpath, file)
                mask_path = os.path.join(gt_dir, file)  # Assumes mask has same filename as image
                pcd_path = os.path.join(pcd_dir, base_name + ".pcd")
                
                # Check existence of required files
                image_exists = os.path.exists(image_path)
                mask_exists = os.path.exists(mask_path)
                pcd_exists = os.path.exists(pcd_path)
                
                if not (image_exists and mask_exists and pcd_exists):
                    print(f"Warning: Missing files for {base_name}: "
                          f"image({image_exists}), mask({mask_exists}), pcd({pcd_exists}). Skipping.")
                    continue
                
                # Determine overall label: "normal" if quality folder is "good", otherwise "abnormal"
                overall_label = "normal" if quality_folder.lower() == "good" else "abnormal"
                
                pair = {
                    "split": split_folder,       
                    "quality": quality_folder,   
                    "label": overall_label,      
                    "image_path": image_path,
                    "mask_path": mask_path,
                    "pcd_path": pcd_path
                }
                pairs.append(pair)
    
    print(f"Total pairs processed: {len(pairs)}")
    return pairs

# Specify your root directory (e.g., the "potato" folder)
root_dir = "/Users/paularamos/Downloads/potato"
pairs = process_potato_folder(root_dir)

# Debug: print out the pairs list to verify paths and metadata
for pair in pairs:
    print(pair)
# Out:
# Processing folder: /Users/paularamos/Downloads/potato/test/good/rgb (split: test, quality: good)
# Looking for PCD files in: /Users/paularamos/Downloads/potato/test/good/pcd
# Processing folder: /Users/paularamos/Downloads/potato/test/cut/rgb (split: test, quality: cut)
# Looking for PCD files in: /Users/paularamos/Downloads/potato/test/cut/pcd
# Processing folder: /Users/paularamos/Downloads/potato/test/combined/rgb (split: test, quality: combined)
# Looking for PCD files in: /Users/paularamos/Downloads/potato/test/combined/pcd
# Processing folder: /Users/paularamos/Downloads/potato/test/contamination/rgb (split: test, quality: contamination)
# Looking for PCD files in: /Users/paularamos/Downloads/potato/test/contamination/pcd
# Processing folder: /Users/paularamos/Downloads/potato/test/hole/rgb (split: test, quality: hole)
# Looking for PCD files in: /Users/paularamos/Downloads/potato/test/hole/pcd
# Processing folder: /Users/paularamos/Downloads/potato/train/good/rgb (split: train, quality: good)
# Looking for PCD files in: /Users/paularamos/Downloads/potato/train/good/pcd
# Warning: Missing files for 176: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 016: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 003: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 163: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 161: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 029: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 015: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 001: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 174: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 212: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 011: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 171: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 013: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 238: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 115: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 049: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 061: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 289: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 048: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 128: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 089: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 249: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 088: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 063: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 117: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 107: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 073: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 098: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 258: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 099: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 066: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 106: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 110: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 104: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 138: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 070: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 272: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 299: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 298: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 267: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 059: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 111: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 108: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 134: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 068: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 054: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 097: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 295: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 294: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 082: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 069: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 135: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 080: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 255: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 296: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 282: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 297: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 268: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 042: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 056: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 122: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 132: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 052: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 091: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 085: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 293: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 084: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 090: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 053: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 125: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 045: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 086: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 092: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 247: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 284: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 044: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 118: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 124: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 157: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 180: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 022: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 142: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 168: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 154: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 020: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 223: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 009: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 182: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 169: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 145: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 179: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 031: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 019: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 024: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 030: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 178: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 150: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 152: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 026: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 225: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 184: image(True), mask(False), pcd(False). Skipping.
# Warning: Missing files for 153: image(True), mask(False), pcd(False). Skipping.
# Processing folder: /Users/paularamos/Downloads/potato/validation/good/rgb (split: validation, quality: good)
# Looking for PCD files in: /Users/paularamos/Downloads/potato/validation/good/pcd
# Warning: Missing files for 002: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 016: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 017: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 003: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 029: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 015: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 001: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 000: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 014: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 028: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 010: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 004: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 005: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 011: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 007: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 013: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 012: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 006: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 023: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 022: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 008: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 020: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 021: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 009: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 031: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 025: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 019: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 018: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 024: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 030: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 026: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 032: image(True), mask(False), pcd(True). Skipping.
# Warning: Missing files for 027: image(True), mask(False), pcd(True). Skipping.
# Total pairs processed: 114
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/002.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/002.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/002.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/016.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/016.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/016.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/017.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/017.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/017.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/003.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/003.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/003.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/015.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/015.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/015.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/001.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/001.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/001.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/000.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/000.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/000.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/014.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/014.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/014.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/010.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/010.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/010.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/004.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/004.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/004.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/005.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/005.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/005.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/011.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/011.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/011.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/007.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/007.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/007.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/013.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/013.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/013.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/012.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/012.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/012.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/006.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/006.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/006.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/008.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/008.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/008.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/020.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/020.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/020.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/021.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/021.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/021.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/009.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/009.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/009.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/019.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/019.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/019.pcd'}
# {'split': 'test', 'quality': 'good', 'label': 'normal', 'image_path': '/Users/paularamos/Downloads/potato/test/good/rgb/018.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/good/gt/018.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/good/pcd/018.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/002.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/002.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/002.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/016.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/016.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/016.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/017.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/017.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/017.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/003.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/003.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/003.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/015.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/015.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/015.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/001.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/001.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/001.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/000.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/000.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/000.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/014.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/014.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/014.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/010.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/010.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/010.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/004.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/004.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/004.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/005.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/005.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/005.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/011.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/011.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/011.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/007.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/007.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/007.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/013.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/013.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/013.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/012.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/012.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/012.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/006.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/006.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/006.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/022.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/022.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/022.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/008.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/008.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/008.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/020.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/020.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/020.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/021.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/021.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/021.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/009.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/009.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/009.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/019.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/019.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/019.pcd'}
# {'split': 'test', 'quality': 'cut', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/cut/rgb/018.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/cut/gt/018.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/cut/pcd/018.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/002.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/002.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/002.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/016.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/016.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/016.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/017.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/017.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/017.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/003.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/003.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/003.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/015.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/015.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/015.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/001.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/001.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/001.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/000.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/000.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/000.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/014.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/014.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/014.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/010.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/010.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/010.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/004.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/004.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/004.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/005.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/005.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/005.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/011.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/011.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/011.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/007.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/007.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/007.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/013.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/013.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/013.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/012.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/012.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/012.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/006.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/006.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/006.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/022.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/022.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/022.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/008.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/008.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/008.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/020.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/020.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/020.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/021.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/021.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/021.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/009.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/009.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/009.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/019.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/019.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/019.pcd'}
# {'split': 'test', 'quality': 'combined', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/combined/rgb/018.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/combined/gt/018.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/combined/pcd/018.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/002.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/002.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/002.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/016.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/016.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/016.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/017.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/017.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/017.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/003.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/003.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/003.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/015.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/015.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/015.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/001.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/001.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/001.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/000.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/000.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/000.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/014.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/014.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/014.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/010.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/010.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/010.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/004.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/004.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/004.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/005.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/005.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/005.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/011.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/011.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/011.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/007.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/007.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/007.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/013.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/013.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/013.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/012.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/012.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/012.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/006.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/006.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/006.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/022.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/022.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/022.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/008.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/008.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/008.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/020.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/020.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/020.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/021.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/021.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/021.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/009.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/009.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/009.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/019.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/019.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/019.pcd'}
# {'split': 'test', 'quality': 'contamination', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/contamination/rgb/018.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/contamination/gt/018.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/contamination/pcd/018.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/002.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/002.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/002.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/016.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/016.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/016.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/017.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/017.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/017.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/003.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/003.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/003.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/015.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/015.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/015.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/001.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/001.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/001.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/000.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/000.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/000.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/014.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/014.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/014.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/010.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/010.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/010.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/004.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/004.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/004.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/005.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/005.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/005.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/011.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/011.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/011.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/007.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/007.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/007.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/013.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/013.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/013.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/012.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/012.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/012.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/006.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/006.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/006.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/022.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/022.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/022.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/008.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/008.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/008.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/020.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/020.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/020.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/021.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/021.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/021.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/009.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/009.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/009.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/019.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/019.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/019.pcd'}
# {'split': 'test', 'quality': 'hole', 'label': 'abnormal', 'image_path': '/Users/paularamos/Downloads/potato/test/hole/rgb/018.png', 'mask_path': '/Users/paularamos/Downloads/potato/test/hole/gt/018.png', 'pcd_path': '/Users/paularamos/Downloads/potato/test/hole/pcd/018.pcd'}

# %% [markdown]
# ### Creating the grouped dataset in FiftyOne

# %%
samples = []
for idx, pair in enumerate(pairs):
    # Create a unique group id for this sample group
    group_id = f"sample_{idx}"
    group = fo.Group()
    
    # --- Image slice ---
    sample_image = fo.Sample(
        filepath=pair["image_path"],
        group=group.element("image")
    )
    sample_image["split"] = pair["split"]
    sample_image["quality"] = pair["quality"]
    sample_image["label"] = pair["label"]
    
    # --- Mask slice ---
    sample_mask = fo.Sample(
        filepath=pair["mask_path"],
        group=group.element("mask")
    )
    sample_mask["split"] = pair["split"]
    sample_mask["quality"] = pair["quality"]
    sample_mask["label"] = pair["label"]
    
    # --- Point Cloud slice ---
    sample_pcd = fo.Sample(
        filepath=pair["pcd_path"],
        group=group.element("pcd")
    )
    sample_pcd["split"] = pair["split"]
    sample_pcd["quality"] = pair["quality"]
    sample_pcd["label"] = pair["label"]
    
    # Add all three slices to the list
    samples.extend([sample_image, sample_mask, sample_pcd])

# Add the grouped samples to the dataset
dataset.add_samples(samples)

# Optionally, launch the FiftyOne App to inspect the dataset.
session = fo.launch_app(dataset)
# Out:
#  100% |█████████████████| 342/342 [95.6ms elapsed, 0s remaining, 3.6K samples/s]
# Connected to FiftyOne on port 5151 at localhost.
# If you are not connecting to a remote session, you may need to start a new session and specify a port
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=1614a1bb-4b6e-4526-8b21-a28940b62c60"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
session = fo.launch_app(dataset)
